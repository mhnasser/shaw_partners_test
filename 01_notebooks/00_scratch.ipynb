# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('../001_modules')

from trainning_imports import *

# %%
train_on_gpu = torch.cuda.is_available()

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16656215612745340983
# xla_global_id: -1
# ]

# %% [markdown]
# ## Packages Versions

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Mohamad Nasser" --iversions
# Out:
# Author: Mohamad Nasser
#
# torchvision: 0.12.0+cu113
# matplotlib : 3.5.1
# sys        : 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# torch      : 1.11.0+cu113
# numpy      : 1.21.5
# tensorflow : 2.11.0

# %% [markdown]
# ## Loading Data

# %%
# Plot de uma imagem
R, C = len(tr_targets.unique()), 10
fig, ax = plt.subplots(R, C, figsize=(10,10))
for label_class, plot_row in enumerate(ax):
    label_x_rows = np.where(tr_targets == label_class)[0]
    for plot_cell in plot_row:
        plot_cell.grid(False); plot_cell.axis('off')
        ix = np.random.choice(label_x_rows)
        x, y = tr_images[ix], tr_targets[ix]
        plot_cell.imshow(x, cmap='gray')
plt.tight_layout()
